# %%
from DSEHW import DSELinearClassifier
import numpy as np
import numpy.random as nr
from sklearn.datasets import make_blobs
import pandas as pd
import seaborn as sns
import scipy.stats as st
import matplotlib.pyplot as plt
from scipy.stats import norm

# %matplotlib inline

# %% [markdown]
# # Update Rules
#
# ## Hyperbolic Tan (derivative)
# ### $$[\frac{2  e^{2x}}{1+e^{2x}}]^2$$
# ## Logistic Regression (derivative)
# ### $$\eta*\sum(y^{(i)}-w_i*x_i)$$

# %%
nr.seed = 42
centers = [[1, 1], [-1, -1]]
X, y = make_blobs(n_samples=500, n_features=2, 
        centers=centers, cluster_std=1.0/8, center_box=(-10.0, 10.0), shuffle=True, random_state=nr.seed)

# %%
df = pd.DataFrame({'x0':X.T[0], 
                   'x1':X.T[1],
                   'y': y,
                   'target':(np.array(['Blue','Red'])[y])})

# %%
fig, ax = plt.subplots(1,figsize=(10,6))
_=sns.scatterplot(x='x0',y='x1',hue='target', data=df,ax=ax,alpha=.5,s=100)

# %%
centers = [[1, 1], [-1, -1]]
X, y = make_blobs(n_samples=500, n_features=2, 
        centers=centers, cluster_std=4, center_box=(-10.0, 10.0), shuffle=True, random_state=None)
df = pd.DataFrame({'x0':X.T[0], 
                   'x1':X.T[1],
                   'y': y,
                   'target':(np.array(['Blue','Red'])[y])})
fig, ax = plt.subplots(1,figsize=(10,6))
_=sns.scatterplot(x='x0',y='x1',hue='target', data=df,ax=ax,alpha=.5,s=100)

# %% [markdown]
# # Perceptron

# %%
obj = DSELinearClassifier(activation='Perceptron', learning_rate=0.01, random_state=nr.seed)
obj.activation
print(obj.classifier.eta)
#X = obj.activation(X)
perceptron = obj.fit(X,y)
perceptronY = obj.classifier.predict(X)
# Out:
# Your activation is defaulted to Perception. You can set the activation argument to 'AdalineGD' or 'HyperTan'
# 0.01

# %%
df = pd.DataFrame({'x0':X.T[0], 
                   'x1':perceptronY,
                   'target':(np.array(['Blue','Red'])[pd.get_dummies(perceptronY)[1]])})
fig, ax = plt.subplots(1,figsize=(10,6))
_=sns.scatterplot(x='x0',y='x1',hue='target', data=df,ax=ax,alpha=.5,s=100)

# %% [markdown]
# # AdalineGD/ Logistic Regression

# %%
centers = [[1, 1], [-1, -1]]
X, y = make_blobs(n_samples=500, n_features=2, 
        centers=centers, cluster_std=4, center_box=(-10.0, 10.0), shuffle=True, random_state=None)
df = pd.DataFrame({'x0':X.T[0], 
                   'x1':X.T[1],
                   'y': y,
                   'target':(np.array(['Blue','Red'])[y])})
fig, ax = plt.subplots(1,figsize=(10,6))
_=sns.scatterplot(x='x0',y='x1',hue='target', data=df,ax=ax,alpha=.5,s=100)

# %%
obj = DSELinearClassifier(activation='AdalineGD', learning_rate=0.01, random_state=nr.seed)
obj.activation
print(obj.classifier.eta)
#X = obj.activation(X)
adaline = obj.fit(X,y)
adalineY = obj.classifier.predict(X)
# Out:
# Your activation is AdalineGD
# 0.01

# %%
df = pd.DataFrame({'x0':X.T[0], 
                   'x1':adalineY,
                   'target':(np.array(['Blue','Red'])[pd.get_dummies(adalineY)[1]])})
fig, ax = plt.subplots(1,figsize=(10,6))
_=sns.scatterplot(x='x0',y='x1',hue='target', data=df,ax=ax,alpha=.5,s=100)

# %% [markdown]
# # HyperTan

# %%
centers = [[1, 1], [-1, -1]]
X, y = make_blobs(n_samples=500, n_features=2, 
        centers=centers, cluster_std=4, center_box=(-10.0, 10.0), shuffle=True, random_state=None)
df = pd.DataFrame({'x0':X.T[0], 
                   'x1':X.T[1],
                   'y': y,
                   'target':(np.array(['Blue','Red'])[y])})
fig, ax = plt.subplots(1,figsize=(10,6))
_=sns.scatterplot(x='x0',y='x1',hue='target', data=df,ax=ax,alpha=.5,s=100)

# %%
obj = DSELinearClassifier(activation='HyperTan', learning_rate=0.01, random_state=nr.seed)
obj.activation
print(obj.classifier.eta)
#X = obj.activation(X)
hyperTan = obj.fit(X,y)
hyperTanY = obj.classifier.predict(X);
# Out:
# Your activation is HyperTan
# 0.01

# %%
df = pd.DataFrame({'x0':X.T[0], 
                   'x1': hyperTanY,
                   'target':(np.array(['Blue','Red'])[pd.get_dummies(hyperTanY)[1]])})
fig, ax = plt.subplots(1,figsize=(10,6))
_=sns.scatterplot(x='x0',y='x1',hue='target', data=df,ax=ax,alpha=.5,s=100)

# %% [markdown]
# # Use summary libraries to compare performance

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.linear_model import Perceptron

X, y = make_blobs(n_samples=500, n_features=2, 
        centers=centers, cluster_std=1.0/8, center_box=(-10.0, 10.0), shuffle=True, random_state=nr.seed)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=nr.seed)

clf = Perceptron(tol=1e-3, random_state=nr.seed)
print(clf.fit(X_train, y_train))
clf.score(X_test, y_test)
# Out:
# Perceptron(alpha=0.0001, class_weight=None, early_stopping=False, eta0=1.0,
#            fit_intercept=True, max_iter=1000, n_iter_no_change=5, n_jobs=None,
#            penalty=None, random_state=42, shuffle=True, tol=0.001,
#            validation_fraction=0.1, verbose=0, warm_start=False)
# 1.0

# %%
from sklearn.linear_model import LogisticRegression

X, y = make_blobs(n_samples=500, n_features=2, 
        centers=centers, cluster_std=1.0/8, center_box=(-10.0, 10.0), shuffle=True, random_state=nr.seed)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=nr.seed)

clf = LogisticRegression(tol=1e-3, random_state=nr.seed)
print(clf.fit(X_train, y_train))
clf.score(X_test, y_test)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=42, solver='lbfgs', tol=0.001, verbose=0,
#                    warm_start=False)
# 1.0

# %%
from sklearn.linear_model import SGDClassifier

X, y = make_blobs(n_samples=500, n_features=2, 
        centers=centers, cluster_std=1.0/8, center_box=(-10.0, 10.0), shuffle=True, random_state=nr.seed)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=nr.seed)

clf = SGDClassifier(tol=1e-3, random_state=nr.seed)
print(clf.fit(X_train, y_train))
clf.score(X_test, y_test)
# Out:
# SGDClassifier(alpha=0.0001, average=False, class_weight=None,
#               early_stopping=False, epsilon=0.1, eta0=0.0, fit_intercept=True,
#               l1_ratio=0.15, learning_rate='optimal', loss='hinge',
#               max_iter=1000, n_iter_no_change=5, n_jobs=None, penalty='l2',
#               power_t=0.5, random_state=42, shuffle=True, tol=0.001,
#               validation_fraction=0.1, verbose=0, warm_start=False)
# 1.0

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn import datasets

from sklearn.linear_model import SGDClassifier, Perceptron
from sklearn.linear_model import LogisticRegression

heldout = [0.95, 0.90, 0.75, 0.50, 0.01]
rounds = 20

X, y = make_blobs(n_samples=500, n_features=2, 
        centers=centers, cluster_std=1.0/8, center_box=(-10.0, 10.0), shuffle=True, random_state=nr.seed)

classifiers = [
    ("SGD", SGDClassifier(max_iter=100)),
    ("Perceptron", Perceptron()),
    ("SAG-LogisticReg", LogisticRegression(solver='sag', tol=1e-1, C=1.e4 / X.shape[0]))
]

xx = 1. - np.array(heldout)

for name, clf in classifiers:
    print("training %s" % name)
    rng = np.random.RandomState(42)
    yy = []
    for i in heldout:
        yy_ = []
        for r in range(rounds):
            X_train, X_test, y_train, y_test = \
                train_test_split(X, y, test_size=i, random_state=rng)
            clf.fit(X_train, y_train)
            y_pred = clf.predict(X_test)
            yy_.append(1 - np.mean(y_pred == y_test))
        yy.append(np.mean(yy_))
    plt.plot(xx, yy, label=name,alpha=.5)

plt.legend(loc="upper right")
plt.xlabel("Proportion train")
plt.ylabel("Test Error Rate")
#plt.scatter(xx,yy)
# Out:
# training SGD
# training Perceptron
# training SAG-LogisticReg
# Text(0, 0.5, 'Test Error Rate')

# %%
for rate in [0.1,0.2,0.4]:
    heldout = [0.95, 0.90, 0.75, 0.50, 0.01]
    rounds = 20

    X, y = make_blobs(n_samples=500, n_features=2, 
            centers=centers, cluster_std=1.0/8, center_box=(-10.0, 10.0), shuffle=True, random_state=nr.seed)

    classifiers = [
        (f"SGD_{rate}", SGDClassifier(max_iter=100,tol=rate)),
        (f"Perceptron_{rate}", Perceptron(tol=rate)),
        (f"SAG-LogisticReg_{rate}", LogisticRegression(solver='sag', tol=rate, C=1.e4 / X.shape[0]))
    ]

    xx = 1. - np.array(heldout)

    for name, clf in classifiers:
        print("training %s" % name)
        rng = np.random.RandomState(42)
        yy = []
        for i in heldout:
            yy_ = []
            for r in range(rounds):
                X_train, X_test, y_train, y_test = \
                    train_test_split(X, y, test_size=i, random_state=rng)
                clf.fit(X_train, y_train)
                y_pred = clf.predict(X_test)
                yy_.append(1 - np.mean(y_pred == y_test))
            yy.append(np.mean(yy_))
        plt.plot(xx, yy, label=name,alpha=.75)

    plt.legend(loc="upper right")
    plt.xlabel("Proportion train")
    plt.ylabel("Test Error Rate")
    #plt.scatter(xx,yy)
# Out:
# training SGD_0.1
# training Perceptron_0.1
# training SAG-LogisticReg_0.1
# training SGD_0.2
# training Perceptron_0.2
# training SAG-LogisticReg_0.2
# training SGD_0.4
# training Perceptron_0.4
# training SAG-LogisticReg_0.4

# %% [markdown]
# # From Simple Gradient Descent, we can see that 0.1 is the best learning rate
# ## Apply rate of 0.1 to a sample_weight of (5,5) and plot. We are testing how well the models can train given an extreme deviance from the initial condition of "1" (1,1) because we have a 2D array.

# %%
sample_weight_last_ten = abs(np.random.randn(len(X)))
type(sample_weight_last_ten)
# Out:
# numpy.ndarray

# %%
X, y = make_blobs(n_samples=500, n_features=2, 
            centers=centers, cluster_std=1.0/8, center_box=(-10.0, 10.0), shuffle=True, random_state=nr.seed)

for rate in [0.1,0.2,0.4]:
    heldout = [0.95, 0.90, 0.75, 0.50, 0.01]
    rounds = 20

    classifiers = [
        (f"SGD_{rate}", SGDClassifier(max_iter=100,tol=rate)),
        (f"Perceptron_{rate}", Perceptron(tol=rate)),
        (f"SAG-LogisticReg_{rate}", LogisticRegression(solver='sag', tol=rate, C=1.e4 / X.shape[0]))
    ]

    xx = 1. - np.array(heldout)

    for name, clf in classifiers:
        print("training %s" % name)
        rng = np.random.RandomState(42)
        yy = []
        for i in heldout:
            yy_ = []
            for r in range(rounds):
                X_train, X_test, y_train, y_test = \
                    train_test_split(X, y, test_size=i, random_state=rng)
                clf.fit(X_train, y_train, sample_weight = float(5))
                y_pred = clf.predict(X_test)
                yy_.append(1 - np.mean(y_pred == y_test))
            yy.append(np.mean(yy_))
        plt.plot(xx, yy, label=name,alpha=.75)

    plt.legend(loc="upper right")
    plt.xlabel("Proportion train")
    plt.ylabel("Test Error Rate")
    #plt.scatter(xx,yy)
# Out:
# training SGD_0.1
# training Perceptron_0.1
# training SAG-LogisticReg_0.1
# training SGD_0.2
# training Perceptron_0.2
# training SAG-LogisticReg_0.2
# training SGD_0.4
# training Perceptron_0.4
# training SAG-LogisticReg_0.4

# %% [markdown]
# ## It's clear that from our models, as long as we choose a training set of at least 50% of the sample we are able to learn quickly, reducing the error to 0%
